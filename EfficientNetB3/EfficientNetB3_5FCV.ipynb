# %%
from sklearn.model_selection import KFold
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras import layers, models
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.optimizers import Adam
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import itertools

# ---- Load and Preprocess Data ----
train_dir = 'D:/Lung_cancer/train'  # Training directory path
target_size = (300, 300)  # Input size for EfficientNetB3
num_classes = 3

# Extract file paths and labels
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=32,  # Temporary batch size
    class_mode='categorical',
    shuffle=False  # To keep track of indices
)
X = np.array(train_generator.filepaths)  # File paths of images
y = np.array(train_generator.classes)    # Corresponding class labels

# ---- Hyperparameter Search Space ----
batch_sizes = [16, 32]
dropout_rates = [0.3, 0.5]
learning_rates = [0.0005, 0.001]
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_params = {}
best_accuracy = 0

# Iterate over all combinations of hyperparameters
for batch_size, dropout_rate, learning_rate in itertools.product(batch_sizes, dropout_rates, learning_rates):
    print(f"Testing batch_size={batch_size}, dropout={dropout_rate}, lr={learning_rate}")
    
    fold_accuracies = []
    fold_losses = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        print(f"\nFold {fold + 1}")
        
        # Split into training and validation sets
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        
        # Load data dynamically
        def load_data(file_paths, labels):
            images = []
            for file in file_paths:
                img = load_img(file, target_size=target_size)
                img = img_to_array(img)
                images.append(img)
            images = np.array(images) / 255.0
            labels = np.eye(num_classes)[labels]
            return images, labels
        
        X_train_images, y_train_labels = load_data(X_train, y_train)
        X_val_images, y_val_labels = load_data(X_val, y_val)
        
        # ---- Define and Compile Model ----
        base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
        base_model.trainable = False
        
        x = base_model.output
        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Dense(512, activation='relu')(x)
        x = layers.Dropout(dropout_rate)(x)
        output = layers.Dense(num_classes, activation='softmax')(x)
        model = models.Model(inputs=base_model.input, outputs=output)
        
        model.compile(
            optimizer=Adam(learning_rate=learning_rate),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        # ---- Train Model ----
        history = model.fit(
            X_train_images, y_train_labels,
            validation_data=(X_val_images, y_val_labels),
            epochs=10,  # Default to 10 epochs
            batch_size=batch_size,
            verbose=1
        )
        
        # ---- Evaluate Model ----
        val_loss, val_accuracy = model.evaluate(X_val_images, y_val_labels, verbose=0)
        print(f"Fold {fold + 1} Accuracy: {val_accuracy * 100:.2f}%")
        print(f"Fold {fold + 1} Loss: {val_loss:.4f}")
        
        fold_accuracies.append(val_accuracy)
        fold_losses.append(val_loss)
    
    # Compute mean accuracy for the current hyperparameter combination
    mean_accuracy = np.mean(fold_accuracies)
    mean_loss = np.mean(fold_losses)
    
    print(f"Mean Accuracy: {mean_accuracy * 100:.2f}%, Mean Loss: {mean_loss:.4f}\n")
    
    # Store best hyperparameters
    if mean_accuracy > best_accuracy:
        best_accuracy = mean_accuracy
        best_params = {
            "batch_size": batch_size,
            "dropout": dropout_rate,
            "learning_rate": learning_rate,
            "accuracy": best_accuracy
        }

# ---- Final Best Parameters ----
print("Best Parameters:")
print(best_params)
# Out:
# Found 406 images belonging to 3 classes.
# Testing batch_size=16, dropout=0.3, lr=0.0005
#
# Fold 1
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.3749 - loss: 1.1600 - val_accuracy: 0.3537 - val_loss: 1.0942
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3197 - loss: 1.1837 - val_accuracy: 0.2927 - val_loss: 1.1235
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.3591 - loss: 1.1267 - val_accuracy: 0.4634 - val_loss: 1.0501
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3235 - loss: 1.1480 - val_accuracy: 0.3537 - val_loss: 1.0975
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3719 - loss: 1.0874 - val_accuracy: 0.3049 - val_loss: 1.0941
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3666 - loss: 1.0967 - val_accuracy: 0.4634 - val_loss: 1.0599
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.2604 - loss: 1.1632 - val_accuracy: 0.2927 - val_loss: 1.0749
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3928 - loss: 1.1078 - val_accuracy: 0.3659 - val_loss: 1.0864
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3276 - loss: 1.0951 - val_accuracy: 0.2927 - val_loss: 1.0977
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3338 - loss: 1.1313 - val_accuracy: 0.4756 - val_loss: 1.0787
# Fold 1 Accuracy: 47.56%
# Fold 1 Loss: 1.0787
#
# Fold 2
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.3463 - loss: 1.1577 - val_accuracy: 0.3086 - val_loss: 1.1198
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3443 - loss: 1.1462 - val_accuracy: 0.3086 - val_loss: 1.1098
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3351 - loss: 1.1446 - val_accuracy: 0.3827 - val_loss: 1.1209
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3307 - loss: 1.1296 - val_accuracy: 0.3827 - val_loss: 1.0862
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.4166 - loss: 1.0899 - val_accuracy: 0.4074 - val_loss: 1.0911
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3095 - loss: 1.1229 - val_accuracy: 0.4074 - val_loss: 1.0794
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3341 - loss: 1.0979 - val_accuracy: 0.3827 - val_loss: 1.0856
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3943 - loss: 1.1302 - val_accuracy: 0.3333 - val_loss: 1.0920
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3558 - loss: 1.0948 - val_accuracy: 0.3827 - val_loss: 1.0811
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3244 - loss: 1.1049 - val_accuracy: 0.3827 - val_loss: 1.0826
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0826
#
# Fold 3
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.3497 - loss: 1.1664 - val_accuracy: 0.3827 - val_loss: 1.1031
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3277 - loss: 1.1350 - val_accuracy: 0.3827 - val_loss: 1.1013
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.3857 - loss: 1.1074 - val_accuracy: 0.2840 - val_loss: 1.1392
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.2932 - loss: 1.1581 - val_accuracy: 0.2840 - val_loss: 1.1466
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.4019 - loss: 1.1075 - val_accuracy: 0.3333 - val_loss: 1.1390
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4174 - loss: 1.0985 - val_accuracy: 0.3951 - val_loss: 1.0796
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.3752 - loss: 1.1024 - val_accuracy: 0.3333 - val_loss: 1.1392
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3848 - loss: 1.1388 - val_accuracy: 0.3333 - val_loss: 1.0957
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3159 - loss: 1.1197 - val_accuracy: 0.3333 - val_loss: 1.0933
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.4173 - loss: 1.0773 - val_accuracy: 0.3210 - val_loss: 1.0817
# Fold 3 Accuracy: 32.10%
# Fold 3 Loss: 1.0817
#
# Fold 4
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.3080 - loss: 1.1832 - val_accuracy: 0.3827 - val_loss: 1.1221
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3331 - loss: 1.1301 - val_accuracy: 0.3827 - val_loss: 1.1100
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3253 - loss: 1.1933 - val_accuracy: 0.3827 - val_loss: 1.1200
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3709 - loss: 1.1267 - val_accuracy: 0.3086 - val_loss: 1.1013
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3791 - loss: 1.1011 - val_accuracy: 0.3457 - val_loss: 1.0916
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3525 - loss: 1.1218 - val_accuracy: 0.3827 - val_loss: 1.0829
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3770 - loss: 1.0939 - val_accuracy: 0.3827 - val_loss: 1.0899
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.3661 - loss: 1.1004 - val_accuracy: 0.3580 - val_loss: 1.0871
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3708 - loss: 1.1188 - val_accuracy: 0.3827 - val_loss: 1.0829
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3769 - loss: 1.0891 - val_accuracy: 0.3086 - val_loss: 1.1183
# Fold 4 Accuracy: 30.86%
# Fold 4 Loss: 1.1183
#
# Fold 5
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.3181 - loss: 1.1913 - val_accuracy: 0.3333 - val_loss: 1.0975
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3241 - loss: 1.1170 - val_accuracy: 0.4815 - val_loss: 1.1121
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3017 - loss: 1.1461 - val_accuracy: 0.3333 - val_loss: 1.1051
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.2554 - loss: 1.1427 - val_accuracy: 0.3333 - val_loss: 1.1334
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3355 - loss: 1.1134 - val_accuracy: 0.3457 - val_loss: 1.1563
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3860 - loss: 1.1155 - val_accuracy: 0.3333 - val_loss: 1.0919
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3253 - loss: 1.1322 - val_accuracy: 0.3333 - val_loss: 1.1472
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3457 - loss: 1.1517 - val_accuracy: 0.3333 - val_loss: 1.1134
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4154 - loss: 1.0988 - val_accuracy: 0.3333 - val_loss: 1.0896
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3568 - loss: 1.1090 - val_accuracy: 0.3333 - val_loss: 1.1198
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1198
# Mean Accuracy: 36.43%, Mean Loss: 1.0962
#
# Testing batch_size=16, dropout=0.3, lr=0.001
#
# Fold 1
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.2854 - loss: 1.2471 - val_accuracy: 0.3049 - val_loss: 1.0990
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3231 - loss: 1.1488 - val_accuracy: 0.2927 - val_loss: 1.1601
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3621 - loss: 1.2081 - val_accuracy: 0.2561 - val_loss: 1.1769
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.2966 - loss: 1.1664 - val_accuracy: 0.3659 - val_loss: 1.0869
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3353 - loss: 1.1134 - val_accuracy: 0.2927 - val_loss: 1.0983
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.3663 - loss: 1.1318 - val_accuracy: 0.4634 - val_loss: 1.0589
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3243 - loss: 1.1262 - val_accuracy: 0.3537 - val_loss: 1.0952
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3672 - loss: 1.1009 - val_accuracy: 0.4634 - val_loss: 1.0686
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3919 - loss: 1.0829 - val_accuracy: 0.3293 - val_loss: 1.1044
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.4294 - loss: 1.0874 - val_accuracy: 0.4634 - val_loss: 1.0788
# Fold 1 Accuracy: 46.34%
# Fold 1 Loss: 1.0788
#
# Fold 2
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.2828 - loss: 1.2585 - val_accuracy: 0.3086 - val_loss: 1.0956
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3876 - loss: 1.1442 - val_accuracy: 0.3086 - val_loss: 1.1726
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4189 - loss: 1.1055 - val_accuracy: 0.3210 - val_loss: 1.1002
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3041 - loss: 1.1290 - val_accuracy: 0.3827 - val_loss: 1.0828
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.4054 - loss: 1.1019 - val_accuracy: 0.3580 - val_loss: 1.1017
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3409 - loss: 1.1394 - val_accuracy: 0.3827 - val_loss: 1.1526
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3843 - loss: 1.1267 - val_accuracy: 0.3827 - val_loss: 1.0841
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3614 - loss: 1.1092 - val_accuracy: 0.3086 - val_loss: 1.0957
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3671 - loss: 1.1123 - val_accuracy: 0.3827 - val_loss: 1.0836
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3808 - loss: 1.0940 - val_accuracy: 0.3827 - val_loss: 1.0827
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0827
#
# Fold 3
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.3823 - loss: 1.1544 - val_accuracy: 0.3333 - val_loss: 1.1250
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3991 - loss: 1.1886 - val_accuracy: 0.3827 - val_loss: 1.1160
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.2830 - loss: 1.2261 - val_accuracy: 0.3457 - val_loss: 1.1063
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3960 - loss: 1.1428 - val_accuracy: 0.3333 - val_loss: 1.1930
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3572 - loss: 1.1448 - val_accuracy: 0.3333 - val_loss: 1.0902
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4149 - loss: 1.1090 - val_accuracy: 0.3827 - val_loss: 1.0821
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3441 - loss: 1.1209 - val_accuracy: 0.3333 - val_loss: 1.1780
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.4197 - loss: 1.1081 - val_accuracy: 0.3827 - val_loss: 1.0831
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3952 - loss: 1.0757 - val_accuracy: 0.3333 - val_loss: 1.1052
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3990 - loss: 1.1093 - val_accuracy: 0.3457 - val_loss: 1.0926
# Fold 3 Accuracy: 34.57%
# Fold 3 Loss: 1.0926
#
# Fold 4
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.3102 - loss: 1.3358 - val_accuracy: 0.4321 - val_loss: 1.0851
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.3000 - loss: 1.1462 - val_accuracy: 0.3827 - val_loss: 1.0940
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.4080 - loss: 1.1024 - val_accuracy: 0.3827 - val_loss: 1.0901
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3356 - loss: 1.1234 - val_accuracy: 0.3827 - val_loss: 1.0881
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3458 - loss: 1.1298 - val_accuracy: 0.3457 - val_loss: 1.0990
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.3664 - loss: 1.1341 - val_accuracy: 0.3827 - val_loss: 1.0842
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.3241 - loss: 1.0980 - val_accuracy: 0.3827 - val_loss: 1.0817
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.3717 - loss: 1.0978 - val_accuracy: 0.3827 - val_loss: 1.1042
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3907 - loss: 1.1006 - val_accuracy: 0.3827 - val_loss: 1.0874
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3174 - loss: 1.1116 - val_accuracy: 0.3827 - val_loss: 1.0902
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0902
#
# Fold 5
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.2996 - loss: 1.3029 - val_accuracy: 0.3333 - val_loss: 1.0965
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.3729 - loss: 1.1409 - val_accuracy: 0.3333 - val_loss: 1.1711
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3149 - loss: 1.1796 - val_accuracy: 0.3086 - val_loss: 1.1161
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3697 - loss: 1.1336 - val_accuracy: 0.3333 - val_loss: 1.1051
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3546 - loss: 1.1057 - val_accuracy: 0.3333 - val_loss: 1.0985
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3612 - loss: 1.0965 - val_accuracy: 0.3333 - val_loss: 1.1467
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3542 - loss: 1.1256 - val_accuracy: 0.3333 - val_loss: 1.1081
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3686 - loss: 1.0978 - val_accuracy: 0.3333 - val_loss: 1.1036
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3089 - loss: 1.1173 - val_accuracy: 0.3333 - val_loss: 1.1128
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3831 - loss: 1.1108 - val_accuracy: 0.3333 - val_loss: 1.1097
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1097
# Mean Accuracy: 38.16%, Mean Loss: 1.0908
#
# Testing batch_size=16, dropout=0.5, lr=0.0005
#
# Fold 1
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 86s 3s/step - accuracy: 0.3142 - loss: 1.1834 - val_accuracy: 0.3902 - val_loss: 1.0945
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3111 - loss: 1.1814 - val_accuracy: 0.2927 - val_loss: 1.1171
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3465 - loss: 1.1941 - val_accuracy: 0.3171 - val_loss: 1.1066
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3399 - loss: 1.1215 - val_accuracy: 0.3293 - val_loss: 1.0905
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3212 - loss: 1.1350 - val_accuracy: 0.2927 - val_loss: 1.1167
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3506 - loss: 1.1021 - val_accuracy: 0.4634 - val_loss: 1.0662
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3192 - loss: 1.1402 - val_accuracy: 0.3902 - val_loss: 1.0874
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3652 - loss: 1.1041 - val_accuracy: 0.3659 - val_loss: 1.0896
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3974 - loss: 1.0856 - val_accuracy: 0.4512 - val_loss: 1.0837
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3770 - loss: 1.1041 - val_accuracy: 0.4634 - val_loss: 1.0738
# Fold 1 Accuracy: 46.34%
# Fold 1 Loss: 1.0738
#
# Fold 2
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.3635 - loss: 1.1363 - val_accuracy: 0.3086 - val_loss: 1.1226
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3906 - loss: 1.1694 - val_accuracy: 0.3086 - val_loss: 1.1482
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3315 - loss: 1.1856 - val_accuracy: 0.3086 - val_loss: 1.1138
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3833 - loss: 1.1150 - val_accuracy: 0.3827 - val_loss: 1.0906
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3911 - loss: 1.1006 - val_accuracy: 0.3086 - val_loss: 1.0897
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3399 - loss: 1.1172 - val_accuracy: 0.3827 - val_loss: 1.0832
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3711 - loss: 1.1117 - val_accuracy: 0.3827 - val_loss: 1.0854
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.2939 - loss: 1.1250 - val_accuracy: 0.3827 - val_loss: 1.0851
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3662 - loss: 1.1137 - val_accuracy: 0.3827 - val_loss: 1.0836
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.4074 - loss: 1.0898 - val_accuracy: 0.3827 - val_loss: 1.0857
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0857
#
# Fold 3
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.3590 - loss: 1.1655 - val_accuracy: 0.3333 - val_loss: 1.1267
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3175 - loss: 1.2091 - val_accuracy: 0.3827 - val_loss: 1.1593
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3885 - loss: 1.1382 - val_accuracy: 0.3333 - val_loss: 1.1296
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.4044 - loss: 1.1078 - val_accuracy: 0.3580 - val_loss: 1.1280
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.3435 - loss: 1.1347 - val_accuracy: 0.3333 - val_loss: 1.0940
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.4326 - loss: 1.0961 - val_accuracy: 0.3333 - val_loss: 1.0941
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3762 - loss: 1.1012 - val_accuracy: 0.3333 - val_loss: 1.1165
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3489 - loss: 1.1060 - val_accuracy: 0.3333 - val_loss: 1.0944
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4171 - loss: 1.0806 - val_accuracy: 0.3333 - val_loss: 1.1078
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3445 - loss: 1.1092 - val_accuracy: 0.3333 - val_loss: 1.0938
# Fold 3 Accuracy: 33.33%
# Fold 3 Loss: 1.0938
#
# Fold 4
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.3626 - loss: 1.1757 - val_accuracy: 0.3086 - val_loss: 1.1927
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3414 - loss: 1.1598 - val_accuracy: 0.3827 - val_loss: 1.0945
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3731 - loss: 1.1216 - val_accuracy: 0.3827 - val_loss: 1.1499
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3458 - loss: 1.1809 - val_accuracy: 0.3086 - val_loss: 1.1156
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.2985 - loss: 1.1371 - val_accuracy: 0.3086 - val_loss: 1.0923
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3765 - loss: 1.1213 - val_accuracy: 0.4074 - val_loss: 1.0852
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3868 - loss: 1.0964 - val_accuracy: 0.3827 - val_loss: 1.1027
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3682 - loss: 1.1061 - val_accuracy: 0.3827 - val_loss: 1.0839
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3915 - loss: 1.0960 - val_accuracy: 0.3827 - val_loss: 1.0869
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3339 - loss: 1.1196 - val_accuracy: 0.3827 - val_loss: 1.0893
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0893
#
# Fold 5
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.4318 - loss: 1.1235 - val_accuracy: 0.3333 - val_loss: 1.2176
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3381 - loss: 1.1792 - val_accuracy: 0.3333 - val_loss: 1.1229
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3189 - loss: 1.1611 - val_accuracy: 0.3333 - val_loss: 1.1535
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3424 - loss: 1.1774 - val_accuracy: 0.3333 - val_loss: 1.0988
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.3746 - loss: 1.1066 - val_accuracy: 0.3333 - val_loss: 1.0962
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.2967 - loss: 1.1482 - val_accuracy: 0.3333 - val_loss: 1.0997
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3590 - loss: 1.1154 - val_accuracy: 0.3333 - val_loss: 1.1099
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3656 - loss: 1.1106 - val_accuracy: 0.3333 - val_loss: 1.0993
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3430 - loss: 1.1087 - val_accuracy: 0.3333 - val_loss: 1.0959
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.3206 - loss: 1.1077 - val_accuracy: 0.3333 - val_loss: 1.1027
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1027
# Mean Accuracy: 37.91%, Mean Loss: 1.0890
#
# Testing batch_size=16, dropout=0.5, lr=0.001
#
# Fold 1
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.3828 - loss: 1.2376 - val_accuracy: 0.2439 - val_loss: 1.2543
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3141 - loss: 1.2161 - val_accuracy: 0.2439 - val_loss: 1.1626
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3538 - loss: 1.2284 - val_accuracy: 0.4634 - val_loss: 1.0687
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3860 - loss: 1.1235 - val_accuracy: 0.2927 - val_loss: 1.1071
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3837 - loss: 1.1026 - val_accuracy: 0.3171 - val_loss: 1.1039
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3633 - loss: 1.1109 - val_accuracy: 0.4634 - val_loss: 1.0754
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3855 - loss: 1.0846 - val_accuracy: 0.2927 - val_loss: 1.0770
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3349 - loss: 1.1104 - val_accuracy: 0.4634 - val_loss: 1.0751
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.4297 - loss: 1.0806 - val_accuracy: 0.4512 - val_loss: 1.0817
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3979 - loss: 1.1006 - val_accuracy: 0.4634 - val_loss: 1.0724
# Fold 1 Accuracy: 46.34%
# Fold 1 Loss: 1.0724
#
# Fold 2
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.3161 - loss: 1.2145 - val_accuracy: 0.3827 - val_loss: 1.1099
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3085 - loss: 1.2416 - val_accuracy: 0.3827 - val_loss: 1.1940
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3671 - loss: 1.1991 - val_accuracy: 0.3086 - val_loss: 1.1345
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.2941 - loss: 1.2117 - val_accuracy: 0.3827 - val_loss: 1.1374
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3207 - loss: 1.1585 - val_accuracy: 0.3827 - val_loss: 1.0860
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.4277 - loss: 1.0980 - val_accuracy: 0.3827 - val_loss: 1.0864
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3665 - loss: 1.0948 - val_accuracy: 0.3086 - val_loss: 1.0907
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.3181 - loss: 1.1077 - val_accuracy: 0.3827 - val_loss: 1.0868
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3764 - loss: 1.0913 - val_accuracy: 0.3827 - val_loss: 1.0914
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3301 - loss: 1.0921 - val_accuracy: 0.3827 - val_loss: 1.0883
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0883
#
# Fold 3
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.3436 - loss: 1.2890 - val_accuracy: 0.3333 - val_loss: 1.2673
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3542 - loss: 1.1816 - val_accuracy: 0.3333 - val_loss: 1.1248
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3207 - loss: 1.1848 - val_accuracy: 0.3333 - val_loss: 1.1114
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3616 - loss: 1.1053 - val_accuracy: 0.3333 - val_loss: 1.1036
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3987 - loss: 1.1117 - val_accuracy: 0.3333 - val_loss: 1.0981
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.4025 - loss: 1.1037 - val_accuracy: 0.3827 - val_loss: 1.0868
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.3464 - loss: 1.1204 - val_accuracy: 0.3333 - val_loss: 1.1216
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3791 - loss: 1.1263 - val_accuracy: 0.3580 - val_loss: 1.1035
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.4531 - loss: 1.0755 - val_accuracy: 0.3333 - val_loss: 1.1063
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3521 - loss: 1.0958 - val_accuracy: 0.3333 - val_loss: 1.0968
# Fold 3 Accuracy: 33.33%
# Fold 3 Loss: 1.0968
#
# Fold 4
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.3492 - loss: 1.2346 - val_accuracy: 0.3086 - val_loss: 1.3596
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.2789 - loss: 1.3341 - val_accuracy: 0.3086 - val_loss: 1.1218
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.3705 - loss: 1.1642 - val_accuracy: 0.3086 - val_loss: 1.1198
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.2973 - loss: 1.1310 - val_accuracy: 0.2222 - val_loss: 1.0888
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3642 - loss: 1.0977 - val_accuracy: 0.3827 - val_loss: 1.0893
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3379 - loss: 1.1092 - val_accuracy: 0.3333 - val_loss: 1.1048
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.3616 - loss: 1.1254 - val_accuracy: 0.4321 - val_loss: 1.0895
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3771 - loss: 1.1032 - val_accuracy: 0.3827 - val_loss: 1.0909
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3930 - loss: 1.0846 - val_accuracy: 0.3827 - val_loss: 1.0891
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.3660 - loss: 1.0887 - val_accuracy: 0.3827 - val_loss: 1.0848
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0848
#
# Fold 5
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.3811 - loss: 1.3434 - val_accuracy: 0.3333 - val_loss: 1.1260
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.3502 - loss: 1.1733 - val_accuracy: 0.3827 - val_loss: 1.0988
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.3804 - loss: 1.1435 - val_accuracy: 0.3333 - val_loss: 1.1017
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.2993 - loss: 1.1231 - val_accuracy: 0.4444 - val_loss: 1.0879
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.3428 - loss: 1.1110 - val_accuracy: 0.3580 - val_loss: 1.0930
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3403 - loss: 1.1160 - val_accuracy: 0.3333 - val_loss: 1.1146
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.4128 - loss: 1.0826 - val_accuracy: 0.3333 - val_loss: 1.1019
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.4358 - loss: 1.0759 - val_accuracy: 0.3333 - val_loss: 1.0981
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3951 - loss: 1.0869

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras import layers, models
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.optimizers import Adam
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import itertools

# ---- Load and Preprocess Data ----
train_dir = 'D:/Lung_cancer/train'  # Training directory path
target_size = (300, 300)  # Input size for EfficientNetB3
num_classes = 3

# Extract file paths and labels
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=32,  # Temporary batch size
    class_mode='categorical',
    shuffle=False  # To keep track of indices
)
X = np.array(train_generator.filepaths)  # File paths of images
y = np.array(train_generator.classes)    # Corresponding class labels

# ---- Hyperparameter Search Space ----
batch_sizes = [32]
dropout_rates = [0.3, 0.5]
learning_rates = [0.0005, 0.001]
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_params = {}
best_accuracy = 0

# Iterate over all combinations of hyperparameters
for batch_size, dropout_rate, learning_rate in itertools.product(batch_sizes, dropout_rates, learning_rates):
    print(f"Testing batch_size={batch_size}, dropout={dropout_rate}, lr={learning_rate}")
    
    fold_accuracies = []
    fold_losses = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        print(f"\nFold {fold + 1}")
        
        # Split into training and validation sets
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        
        # Load data dynamically
        def load_data(file_paths, labels):
            images = []
            for file in file_paths:
                img = load_img(file, target_size=target_size)
                img = img_to_array(img)
                images.append(img)
            images = np.array(images) / 255.0
            labels = np.eye(num_classes)[labels]
            return images, labels
        
        X_train_images, y_train_labels = load_data(X_train, y_train)
        X_val_images, y_val_labels = load_data(X_val, y_val)
        
        # ---- Define and Compile Model ----
        base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
        base_model.trainable = False
        
        x = base_model.output
        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Dense(512, activation='relu')(x)
        x = layers.Dropout(dropout_rate)(x)
        output = layers.Dense(num_classes, activation='softmax')(x)
        model = models.Model(inputs=base_model.input, outputs=output)
        
        model.compile(
            optimizer=Adam(learning_rate=learning_rate),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        # ---- Train Model ----
        history = model.fit(
            X_train_images, y_train_labels,
            validation_data=(X_val_images, y_val_labels),
            epochs=10,  # Default to 10 epochs
            batch_size=batch_size,
            verbose=1
        )
        
        # ---- Evaluate Model ----
        val_loss, val_accuracy = model.evaluate(X_val_images, y_val_labels, verbose=0)
        print(f"Fold {fold + 1} Accuracy: {val_accuracy * 100:.2f}%")
        print(f"Fold {fold + 1} Loss: {val_loss:.4f}")
        
        fold_accuracies.append(val_accuracy)
        fold_losses.append(val_loss)
    
    # Compute mean accuracy for the current hyperparameter combination
    mean_accuracy = np.mean(fold_accuracies)
    mean_loss = np.mean(fold_losses)
    
    print(f"Mean Accuracy: {mean_accuracy * 100:.2f}%, Mean Loss: {mean_loss:.4f}\n")
    
    # Store best hyperparameters
    if mean_accuracy > best_accuracy:
        best_accuracy = mean_accuracy
        best_params = {
            "batch_size": batch_size,
            "dropout": dropout_rate,
            "learning_rate": learning_rate,
            "accuracy": best_accuracy
        }

# ---- Final Best Parameters ----
print("Best Parameters:")
print(best_params)
# Out:
# Found 406 images belonging to 3 classes.
# Testing batch_size=32, dropout=0.3, lr=0.0005
#
# Fold 1
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.3545 - loss: 1.1531 - val_accuracy: 0.4634 - val_loss: 1.0676
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 46s 4s/step - accuracy: 0.3748 - loss: 1.1441 - val_accuracy: 0.2927 - val_loss: 1.1305
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.3256 - loss: 1.1730 - val_accuracy: 0.4634 - val_loss: 1.0886
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3571 - loss: 1.1519 - val_accuracy: 0.2683 - val_loss: 1.1195
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3758 - loss: 1.1262 - val_accuracy: 0.4634 - val_loss: 1.0684
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3248 - loss: 1.1392 - val_accuracy: 0.3537 - val_loss: 1.0950
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.2995 - loss: 1.1213 - val_accuracy: 0.2927 - val_loss: 1.0954
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.3618 - loss: 1.1041 - val_accuracy: 0.4634 - val_loss: 1.0676
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.3675 - loss: 1.0891 - val_accuracy: 0.3049 - val_loss: 1.0916
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3916 - loss: 1.0870 - val_accuracy: 0.4878 - val_loss: 1.0704
# Fold 1 Accuracy: 48.78%
# Fold 1 Loss: 1.0704
#
# Fold 2
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 60s 4s/step - accuracy: 0.3773 - loss: 1.1587 - val_accuracy: 0.3086 - val_loss: 1.1668
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3251 - loss: 1.1506 - val_accuracy: 0.3086 - val_loss: 1.1300
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.3299 - loss: 1.1264 - val_accuracy: 0.3827 - val_loss: 1.1303
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3048 - loss: 1.1507 - val_accuracy: 0.4568 - val_loss: 1.0883
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.3464 - loss: 1.1112 - val_accuracy: 0.3086 - val_loss: 1.0993
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 46s 4s/step - accuracy: 0.3335 - loss: 1.1118 - val_accuracy: 0.3827 - val_loss: 1.0830
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 46s 4s/step - accuracy: 0.4106 - loss: 1.0747 - val_accuracy: 0.3086 - val_loss: 1.0980
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.2996 - loss: 1.1115 - val_accuracy: 0.3827 - val_loss: 1.0881
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.3330 - loss: 1.0917 - val_accuracy: 0.3827 - val_loss: 1.0772
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.3611 - loss: 1.1030 - val_accuracy: 0.3827 - val_loss: 1.0803
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0803
#
# Fold 3
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.3868 - loss: 1.1680 - val_accuracy: 0.3827 - val_loss: 1.0864
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3158 - loss: 1.1397 - val_accuracy: 0.3333 - val_loss: 1.1636
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3899 - loss: 1.1056 - val_accuracy: 0.3827 - val_loss: 1.0848
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3271 - loss: 1.1114 - val_accuracy: 0.3333 - val_loss: 1.1109
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4116 - loss: 1.0870 - val_accuracy: 0.3704 - val_loss: 1.0834
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3630 - loss: 1.0959 - val_accuracy: 0.3333 - val_loss: 1.0885
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.4208 - loss: 1.0790 - val_accuracy: 0.3210 - val_loss: 1.0819
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.4061 - loss: 1.0842 - val_accuracy: 0.3333 - val_loss: 1.0855
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.4312 - loss: 1.0804 - val_accuracy: 0.3333 - val_loss: 1.0894
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3131 - loss: 1.1082 - val_accuracy: 0.3333 - val_loss: 1.0876
# Fold 3 Accuracy: 33.33%
# Fold 3 Loss: 1.0876
#
# Fold 4
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3525 - loss: 1.1460 - val_accuracy: 0.3086 - val_loss: 1.1639
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3322 - loss: 1.1521 - val_accuracy: 0.3827 - val_loss: 1.1012
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3404 - loss: 1.1179 - val_accuracy: 0.3827 - val_loss: 1.0783
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3787 - loss: 1.1173 - val_accuracy: 0.3086 - val_loss: 1.0915
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3264 - loss: 1.1173 - val_accuracy: 0.3827 - val_loss: 1.0961
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3603 - loss: 1.1271 - val_accuracy: 0.4198 - val_loss: 1.0802
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3281 - loss: 1.1133 - val_accuracy: 0.3827 - val_loss: 1.0871
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.4028 - loss: 1.1014 - val_accuracy: 0.3827 - val_loss: 1.0930
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3578 - loss: 1.1079 - val_accuracy: 0.4444 - val_loss: 1.0765
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3474 - loss: 1.1104 - val_accuracy: 0.3086 - val_loss: 1.0869
# Fold 4 Accuracy: 30.86%
# Fold 4 Loss: 1.0869
#
# Fold 5
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3172 - loss: 1.2226 - val_accuracy: 0.3333 - val_loss: 1.1533
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3818 - loss: 1.1294 - val_accuracy: 0.3333 - val_loss: 1.1033
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3830 - loss: 1.1050 - val_accuracy: 0.3333 - val_loss: 1.1647
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3535 - loss: 1.1599 - val_accuracy: 0.3333 - val_loss: 1.0944
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3705 - loss: 1.1093 - val_accuracy: 0.3333 - val_loss: 1.0941
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3549 - loss: 1.0940 - val_accuracy: 0.3333 - val_loss: 1.0987
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3494 - loss: 1.1024 - val_accuracy: 0.3333 - val_loss: 1.1148
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3753 - loss: 1.0907 - val_accuracy: 0.3333 - val_loss: 1.0991
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 353s 35s/step - accuracy: 0.3127 - loss: 1.1032 - val_accuracy: 0.3333 - val_loss: 1.0955
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 47s 4s/step - accuracy: 0.3705 - loss: 1.0842 - val_accuracy: 0.3333 - val_loss: 1.1090
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1090
# Mean Accuracy: 36.92%, Mean Loss: 1.0868
#
# Testing batch_size=32, dropout=0.3, lr=0.001
#
# Fold 1
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.3904 - loss: 1.3030 - val_accuracy: 0.2439 - val_loss: 1.2130
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3667 - loss: 1.1754 - val_accuracy: 0.4634 - val_loss: 1.1017
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3487 - loss: 1.1683 - val_accuracy: 0.2439 - val_loss: 1.1141
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3785 - loss: 1.1068 - val_accuracy: 0.4634 - val_loss: 1.0693
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3623 - loss: 1.0888 - val_accuracy: 0.3659 - val_loss: 1.0911
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.2948 - loss: 1.1196 - val_accuracy: 0.4634 - val_loss: 1.0696
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.2983 - loss: 1.1471 - val_accuracy: 0.2927 - val_loss: 1.0882
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3323 - loss: 1.1237 - val_accuracy: 0.5122 - val_loss: 1.0734
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3523 - loss: 1.1195 - val_accuracy: 0.2927 - val_loss: 1.0888
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3399 - loss: 1.0969 - val_accuracy: 0.4756 - val_loss: 1.0806
# Fold 1 Accuracy: 47.56%
# Fold 1 Loss: 1.0806
#
# Fold 2
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.3775 - loss: 1.2701 - val_accuracy: 0.3827 - val_loss: 1.1890
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3174 - loss: 1.2321 - val_accuracy: 0.3827 - val_loss: 1.1048
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3565 - loss: 1.1427 - val_accuracy: 0.3086 - val_loss: 1.0927
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3570 - loss: 1.0943 - val_accuracy: 0.3086 - val_loss: 1.1125
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3664 - loss: 1.1381 - val_accuracy: 0.3086 - val_loss: 1.2361
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3520 - loss: 1.1843 - val_accuracy: 0.3704 - val_loss: 1.0916
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3034 - loss: 1.1124 - val_accuracy: 0.3827 - val_loss: 1.0834
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3247 - loss: 1.1196 - val_accuracy: 0.3827 - val_loss: 1.0903
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3610 - loss: 1.0971 - val_accuracy: 0.3086 - val_loss: 1.0874
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3324 - loss: 1.1015 - val_accuracy: 0.3827 - val_loss: 1.0797
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0797
#
# Fold 3
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3218 - loss: 1.2828 - val_accuracy: 0.2840 - val_loss: 1.2217
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.2811 - loss: 1.2137 - val_accuracy: 0.3333 - val_loss: 1.1616
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3778 - loss: 1.1322 - val_accuracy: 0.2963 - val_loss: 1.1086
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3552 - loss: 1.1244 - val_accuracy: 0.3333 - val_loss: 1.1225
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.3936 - loss: 1.1157 - val_accuracy: 0.4074 - val_loss: 1.0819
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3651 - loss: 1.1012 - val_accuracy: 0.3333 - val_loss: 1.0970
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3612 - loss: 1.1044 - val_accuracy: 0.3333 - val_loss: 1.0921
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3737 - loss: 1.0874 - val_accuracy: 0.3333 - val_loss: 1.1029
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4187 - loss: 1.0787 - val_accuracy: 0.3457 - val_loss: 1.0850
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3344 - loss: 1.1278 - val_accuracy: 0.3827 - val_loss: 1.0809
# Fold 3 Accuracy: 38.27%
# Fold 3 Loss: 1.0809
#
# Fold 4
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.3721 - loss: 1.1703 - val_accuracy: 0.3827 - val_loss: 1.0911
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3482 - loss: 1.1502 - val_accuracy: 0.3827 - val_loss: 1.0868
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3189 - loss: 1.1259 - val_accuracy: 0.3827 - val_loss: 1.0844
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.2990 - loss: 1.1378 - val_accuracy: 0.3827 - val_loss: 1.0967
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3888 - loss: 1.1350 - val_accuracy: 0.3086 - val_loss: 1.1865
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3047 - loss: 1.1921 - val_accuracy: 0.3827 - val_loss: 1.0991
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3687 - loss: 1.1354 - val_accuracy: 0.4198 - val_loss: 1.0870
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3916 - loss: 1.0824 - val_accuracy: 0.3086 - val_loss: 1.0969
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3610 - loss: 1.0944 - val_accuracy: 0.3827 - val_loss: 1.0851
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3940 - loss: 1.0936 - val_accuracy: 0.3827 - val_loss: 1.0945
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0945
#
# Fold 5
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.3481 - loss: 1.2133 - val_accuracy: 0.3333 - val_loss: 1.1504
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4050 - loss: 1.1135 - val_accuracy: 0.3333 - val_loss: 1.1134
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3715 - loss: 1.1257 - val_accuracy: 0.3333 - val_loss: 1.1118
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3964 - loss: 1.1188 - val_accuracy: 0.3333 - val_loss: 1.0869
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3251 - loss: 1.1069 - val_accuracy: 0.3333 - val_loss: 1.1240
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3471 - loss: 1.1251 - val_accuracy: 0.4321 - val_loss: 1.0833
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3906 - loss: 1.0910 - val_accuracy: 0.3333 - val_loss: 1.0882
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3501 - loss: 1.0992 - val_accuracy: 0.3333 - val_loss: 1.0953
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3788 - loss: 1.0917 - val_accuracy: 0.3333 - val_loss: 1.0858
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3500 - loss: 1.0998 - val_accuracy: 0.3333 - val_loss: 1.1137
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1137
# Mean Accuracy: 39.14%, Mean Loss: 1.0899
#
# Testing batch_size=32, dropout=0.5, lr=0.0005
#
# Fold 1
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3469 - loss: 1.1789 - val_accuracy: 0.4634 - val_loss: 1.1002
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3557 - loss: 1.1936 - val_accuracy: 0.2927 - val_loss: 1.1280
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3446 - loss: 1.1452 - val_accuracy: 0.4634 - val_loss: 1.0559
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3818 - loss: 1.1028 - val_accuracy: 0.2927 - val_loss: 1.1190
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3382 - loss: 1.1655 - val_accuracy: 0.5122 - val_loss: 1.0822
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3555 - loss: 1.1215 - val_accuracy: 0.4634 - val_loss: 1.0623
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3193 - loss: 1.1233 - val_accuracy: 0.3780 - val_loss: 1.0787
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3557 - loss: 1.1064 - val_accuracy: 0.4634 - val_loss: 1.0677
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3533 - loss: 1.1234 - val_accuracy: 0.2927 - val_loss: 1.0837
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.4117 - loss: 1.0963 - val_accuracy: 0.4634 - val_loss: 1.0649
# Fold 1 Accuracy: 46.34%
# Fold 1 Loss: 1.0649
#
# Fold 2
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.3532 - loss: 1.1348 - val_accuracy: 0.3827 - val_loss: 1.1069
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.4071 - loss: 1.1175 - val_accuracy: 0.3086 - val_loss: 1.1470
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3105 - loss: 1.1600 - val_accuracy: 0.4198 - val_loss: 1.0911
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3077 - loss: 1.1401 - val_accuracy: 0.3827 - val_loss: 1.0941
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3258 - loss: 1.1531 - val_accuracy: 0.3827 - val_loss: 1.0843
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3659 - loss: 1.0990 - val_accuracy: 0.3827 - val_loss: 1.0827
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3487 - loss: 1.1322 - val_accuracy: 0.3086 - val_loss: 1.0902
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3715 - loss: 1.0991 - val_accuracy: 0.4074 - val_loss: 1.0826
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.2928 - loss: 1.1387 - val_accuracy: 0.3827 - val_loss: 1.0826
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4316 - loss: 1.0998 - val_accuracy: 0.3827 - val_loss: 1.0833
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0833
#
# Fold 3
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 58s 4s/step - accuracy: 0.3992 - loss: 1.1448 - val_accuracy: 0.3333 - val_loss: 1.1723
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3381 - loss: 1.1174 - val_accuracy: 0.3333 - val_loss: 1.0958
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3562 - loss: 1.1116 - val_accuracy: 0.3333 - val_loss: 1.0955
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3485 - loss: 1.1142 - val_accuracy: 0.3333 - val_loss: 1.1105
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.4078 - loss: 1.1133 - val_accuracy: 0.2593 - val_loss: 1.0840
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.4353 - loss: 1.1042 - val_accuracy: 0.3333 - val_loss: 1.0946
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.2891 - loss: 1.1245 - val_accuracy: 0.3333 - val_loss: 1.0921
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3915 - loss: 1.0983 - val_accuracy: 0.3333 - val_loss: 1.0839
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4431 - loss: 1.0920 - val_accuracy: 0.3333 - val_loss: 1.0930
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4014 - loss: 1.0958 - val_accuracy: 0.3333 - val_loss: 1.0869
# Fold 3 Accuracy: 33.33%
# Fold 3 Loss: 1.0869
#
# Fold 4
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.3170 - loss: 1.1654 - val_accuracy: 0.3827 - val_loss: 1.1122
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3284 - loss: 1.1675 - val_accuracy: 0.4321 - val_loss: 1.0909
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.4223 - loss: 1.0789 - val_accuracy: 0.3210 - val_loss: 1.0889
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.2803 - loss: 1.1734 - val_accuracy: 0.3827 - val_loss: 1.0857
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.2907 - loss: 1.1384 - val_accuracy: 0.3827 - val_loss: 1.0821
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3537 - loss: 1.1262 - val_accuracy: 0.3827 - val_loss: 1.0871
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.3535 - loss: 1.1114 - val_accuracy: 0.3827 - val_loss: 1.0848
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.2951 - loss: 1.1301 - val_accuracy: 0.3951 - val_loss: 1.0863
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4117 - loss: 1.0982 - val_accuracy: 0.3827 - val_loss: 1.0963
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4135 - loss: 1.0872 - val_accuracy: 0.3827 - val_loss: 1.0848
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0848
#
# Fold 5
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3852 - loss: 1.1342 - val_accuracy: 0.3333 - val_loss: 1.2380
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3891 - loss: 1.1737 - val_accuracy: 0.3333 - val_loss: 1.0957
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3829 - loss: 1.1319 - val_accuracy: 0.3333 - val_loss: 1.1595
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3785 - loss: 1.1389 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3211 - loss: 1.1507 - val_accuracy: 0.3333 - val_loss: 1.1035
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3480 - loss: 1.1202 - val_accuracy: 0.3333 - val_loss: 1.0917
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3793 - loss: 1.1062 - val_accuracy: 0.3333 - val_loss: 1.0987
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3080 - loss: 1.1387 - val_accuracy: 0.3333 - val_loss: 1.1019
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3189 - loss: 1.1310 - val_accuracy: 0.3333 - val_loss: 1.0902
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3299 - loss: 1.1044 - val_accuracy: 0.3333 - val_loss: 1.1003
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1003
# Mean Accuracy: 37.91%, Mean Loss: 1.0840
#
# Testing batch_size=32, dropout=0.5, lr=0.001
#
# Fold 1
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 63s 4s/step - accuracy: 0.3493 - loss: 1.3109 - val_accuracy: 0.2439 - val_loss: 1.1331
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.2834 - loss: 1.1975 - val_accuracy: 0.4756 - val_loss: 1.0820
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3712 - loss: 1.1450 - val_accuracy: 0.3049 - val_loss: 1.1249
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3076 - loss: 1.1494 - val_accuracy: 0.5000 - val_loss: 1.0706
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3420 - loss: 1.1512 - val_accuracy: 0.2927 - val_loss: 1.0868
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3442 - loss: 1.1198 - val_accuracy: 0.4756 - val_loss: 1.0811
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3447 - loss: 1.1185 - val_accuracy: 0.4756 - val_loss: 1.0742
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3700 - loss: 1.1182 - val_accuracy: 0.4878 - val_loss: 1.0806
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3307 - loss: 1.1101 - val_accuracy: 0.5000 - val_loss: 1.0785
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4127 - loss: 1.0853 - val_accuracy: 0.3537 - val_loss: 1.0857
# Fold 1 Accuracy: 35.37%
# Fold 1 Loss: 1.0857
#
# Fold 2
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3191 - loss: 1.2602 - val_accuracy: 0.3086 - val_loss: 1.1432
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4109 - loss: 1.1240 - val_accuracy: 0.3827 - val_loss: 1.1265
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3300 - loss: 1.1580 - val_accuracy: 0.3827 - val_loss: 1.0839
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3869 - loss: 1.1155 - val_accuracy: 0.3827 - val_loss: 1.0831
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3503 - loss: 1.1424 - val_accuracy: 0.3827 - val_loss: 1.0836
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4220 - loss: 1.0814 - val_accuracy: 0.3457 - val_loss: 1.0847
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.3683 - loss: 1.1181 - val_accuracy: 0.3827 - val_loss: 1.0884
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3731 - loss: 1.1086 - val_accuracy: 0.3827 - val_loss: 1.0849
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3563 - loss: 1.0976 - val_accuracy: 0.3457 - val_loss: 1.0949
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3151 - loss: 1.1033 - val_accuracy: 0.3827 - val_loss: 1.0913
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0913
#
# Fold 3
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.4196 - loss: 1.1594 - val_accuracy: 0.3333 - val_loss: 1.1161
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3773 - loss: 1.1771 - val_accuracy: 0.2840 - val_loss: 1.1388
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3397 - loss: 1.2023 - val_accuracy: 0.3827 - val_loss: 1.1094
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.2783 - loss: 1.2124 - val_accuracy: 0.3333 - val_loss: 1.1247
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4274 - loss: 1.1037 - val_accuracy: 0.3333 - val_loss: 1.0919
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3585 - loss: 1.1288 - val_accuracy: 0.2716 - val_loss: 1.0842
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3986 - loss: 1.1064 - val_accuracy: 0.3333 - val_loss: 1.1020
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3571 - loss: 1.1076 - val_accuracy: 0.3333 - val_loss: 1.0941
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3224 - loss: 1.1365 - val_accuracy: 0.3333 - val_loss: 1.0979
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3871 - loss: 1.0924 - val_accuracy: 0.3210 - val_loss: 1.0832
# Fold 3 Accuracy: 32.10%
# Fold 3 Loss: 1.0832
#
# Fold 4
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 65s 4s/step - accuracy: 0.3309 - loss: 1.1811 - val_accuracy: 0.3086 - val_loss: 1.1029
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3298 - loss: 1.2437 - val_accuracy: 0.3827 - val_loss: 1.1918
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3613 - loss: 1.2112 - val_accuracy: 0.3580 - val_loss: 1.0900
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3574 - loss: 1.1807 - val_accuracy: 0.3580 - val_loss: 1.0913
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3370 - loss: 1.1251 - val_accuracy: 0.3827 - val_loss: 1.0829
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3470 - loss: 1.1257 - val_accuracy: 0.3827 - val_loss: 1.0976
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3221 - loss: 1.1522 - val_accuracy: 0.3827 - val_loss: 1.0905
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3662 - loss: 1.1342 - val_accuracy: 0.3827 - val_loss: 1.0872
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4182 - loss: 1.0960 - val_accuracy: 0.3086 - val_loss: 1.0990
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3055 - loss: 1.1045 - val_accuracy: 0.3827 - val_loss: 1.0886
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0886
#
# Fold 5
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.3459 - loss: 1.2821 - val_accuracy: 0.3333 - val_loss: 1.1840
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3773 - loss: 1.1503 - val_accuracy: 0.3333 - val_loss: 1.1598
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3529 - loss: 1.1781 - val_accuracy: 0.3333 - val_loss: 1.1292
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.3494 - loss: 1.1458 - val_accuracy: 0.3333 - val_loss: 1.1042
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4018 - loss: 1.0992 - val_accuracy: 0.3333 - val_loss: 1.1006
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3678 - loss: 1.1065 - val_accuracy: 0.3333 - val_loss: 1.0919
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3895 - loss: 1.1126 - val_accuracy: 0.3333 - val_loss: 1.0994
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3351 - loss: 1.1151 - val_accuracy: 0.3333 - val_loss: 1.0950
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.3654 - loss: 1.1020 - val_accuracy: 0.3333 - val_loss: 1.1025
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.3751 - loss: 1.0841 - val_accuracy: 0.3333 - val_loss: 1.1023
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1023
# Mean Accuracy: 35.47%, Mean Loss: 1.0902
#
# Best Parameters:
# {'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.001, 'accuracy': 0.39141825437545774}
