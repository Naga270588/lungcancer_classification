# %%
from sklearn.model_selection import KFold
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.optimizers import Adam
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import itertools
import tensorflow as tf

# ---- Load and Preprocess Data ----
train_dir = 'D:/Lung_cancer/train'  # Training directory path
target_size = (224, 224)  # Input size for ResNet50
num_classes = 3

# Extract file paths and labels
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=32,  # Temporary batch size
    class_mode='categorical',
    shuffle=False  # To keep track of indices
)
X = np.array(train_generator.filepaths)  # File paths of images
y = np.array(train_generator.classes)    # Corresponding class labels

# ---- Hyperparameter Search Space ----
batch_sizes = [16, 32]
dropout_rates = [0.3, 0.5]
learning_rates = [0.0005, 0.001]
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_params = {}
best_accuracy = 0

# ✅ Custom Multi-Head Attention Layer (Fixed)
class MultiHeadAttentionLayer(layers.Layer):
    def __init__(self, num_heads=4, key_dim=32):
        super(MultiHeadAttentionLayer, self).__init__()
        self.attention = layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)

    def call(self, inputs):
        inputs = tf.expand_dims(inputs, axis=1)  # Ensure proper shape
        attn_output = self.attention(inputs, inputs)
        return tf.squeeze(attn_output, axis=1)  # Restore shape

# Iterate over all combinations of hyperparameters
for batch_size, dropout_rate, learning_rate in itertools.product(batch_sizes, dropout_rates, learning_rates):
    print(f"Testing batch_size={batch_size}, dropout={dropout_rate}, lr={learning_rate}")
    
    fold_accuracies = []
    fold_losses = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        print(f"\nFold {fold + 1}")
        
        # Split into training and validation sets
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        
        # Load data dynamically
        def load_data(file_paths, labels):
            images = []
            for file in file_paths:
                img = load_img(file, target_size=target_size)
                img = img_to_array(img)
                images.append(img)
            images = np.array(images) / 255.0
            labels = np.eye(num_classes)[labels]
            return images, labels
        
        X_train_images, y_train_labels = load_data(X_train, y_train)
        X_val_images, y_val_labels = load_data(X_val, y_val)
        
        # ---- Define and Compile Model ----
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        base_model.trainable = False
        
        x = base_model.output
        x = layers.Flatten()(x)  # Keeps spatial dimensions for attention
        x = layers.Dense(512, activation='relu')(x)
        x = MultiHeadAttentionLayer()(x)  # ✅ Using custom Keras Layer for Attention
        x = layers.Dropout(dropout_rate)(x)
        
        output = layers.Dense(num_classes, activation='softmax')(x)
        model = models.Model(inputs=base_model.input, outputs=output)
        
        model.compile(
            optimizer=Adam(learning_rate=learning_rate),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        # ---- Train Model ----
        history = model.fit(
            X_train_images, y_train_labels,
            validation_data=(X_val_images, y_val_labels),
            epochs=10,
            batch_size=batch_size,
            verbose=1
        )
        
        # ---- Evaluate Model ----
        val_loss, val_accuracy = model.evaluate(X_val_images, y_val_labels, verbose=0)
        print(f"Fold {fold + 1} Accuracy: {val_accuracy * 100:.2f}%")
        print(f"Fold {fold + 1} Loss: {val_loss:.4f}")
        
        fold_accuracies.append(val_accuracy)
        fold_losses.append(val_loss)
    
    # Compute mean accuracy for the current hyperparameter combination
    mean_accuracy = np.mean(fold_accuracies)
    mean_loss = np.mean(fold_losses)
    
    print(f"Mean Accuracy: {mean_accuracy * 100:.2f}%, Mean Loss: {mean_loss:.4f}\n")
    
    # Store best hyperparameters
    if mean_accuracy > best_accuracy:
        best_accuracy = mean_accuracy
        best_params = {
            "batch_size": batch_size,
            "dropout": dropout_rate,
            "learning_rate": learning_rate,
            "accuracy": best_accuracy
        }

# ---- Final Best Parameters ----
print("Best Parameters:")
print(best_params)
# Out:
# Found 406 images belonging to 3 classes.
# Testing batch_size=16, dropout=0.3, lr=0.0005
#
# Fold 1
# WARNING:tensorflow:From C:\Users\Milanjyoti\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4149 - loss: 1.2321 - val_accuracy: 0.2439 - val_loss: 1.2351
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3020 - loss: 1.1214 - val_accuracy: 0.4634 - val_loss: 1.0637
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3387 - loss: 1.0938 - val_accuracy: 0.5000 - val_loss: 1.0846
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4233 - loss: 1.0885 - val_accuracy: 0.4634 - val_loss: 1.0604
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3794 - loss: 1.0860 - val_accuracy: 0.4390 - val_loss: 1.0604
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4109 - loss: 1.0667 - val_accuracy: 0.3293 - val_loss: 1.0911
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4045 - loss: 1.0787 - val_accuracy: 0.4634 - val_loss: 1.0346
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3963 - loss: 1.0699 - val_accuracy: 0.4146 - val_loss: 1.0493
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4174 - loss: 1.0759 - val_accuracy: 0.4878 - val_loss: 1.0424
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4007 - loss: 1.0583 - val_accuracy: 0.4512 - val_loss: 1.0450
# Fold 1 Accuracy: 45.12%
# Fold 1 Loss: 1.0450
#
# Fold 2
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3701 - loss: 1.2592 - val_accuracy: 0.3827 - val_loss: 1.0930
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3293 - loss: 1.0973 - val_accuracy: 0.3086 - val_loss: 1.0980
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3581 - loss: 1.0968 - val_accuracy: 0.3827 - val_loss: 1.0963
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4246 - loss: 1.0873 - val_accuracy: 0.3827 - val_loss: 1.0943
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3632 - loss: 1.0933 - val_accuracy: 0.3827 - val_loss: 1.0946
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3814 - loss: 1.0952 - val_accuracy: 0.3827 - val_loss: 1.0940
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.3608 - loss: 1.0969 - val_accuracy: 0.3827 - val_loss: 1.0942
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.4152 - loss: 1.0901 - val_accuracy: 0.3827 - val_loss: 1.0943
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3625 - loss: 1.0987 - val_accuracy: 0.3827 - val_loss: 1.0950
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.3787 - loss: 1.0904 - val_accuracy: 0.3827 - val_loss: 1.0958
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0958
#
# Fold 3
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.3606 - loss: 1.4961 - val_accuracy: 0.4074 - val_loss: 1.0879
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3331 - loss: 1.1031 - val_accuracy: 0.3333 - val_loss: 1.0939
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4138 - loss: 1.0868 - val_accuracy: 0.3333 - val_loss: 1.0828
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3870 - loss: 1.0830 - val_accuracy: 0.3333 - val_loss: 1.1426
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3973 - loss: 1.1106 - val_accuracy: 0.4321 - val_loss: 1.0810
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3928 - loss: 1.0775 - val_accuracy: 0.3333 - val_loss: 1.0809
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3854 - loss: 1.0671 - val_accuracy: 0.4568 - val_loss: 1.0619
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3659 - loss: 1.1052 - val_accuracy: 0.3086 - val_loss: 1.1020
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4141 - loss: 1.0930 - val_accuracy: 0.3827 - val_loss: 1.1002
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3259 - loss: 1.1040 - val_accuracy: 0.3580 - val_loss: 1.0960
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3593 - loss: 1.0992 - val_accuracy: 0.3827 - val_loss: 1.0942
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3502 - loss: 1.0969 - val_accuracy: 0.3827 - val_loss: 1.0947
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3410 - loss: 1.0984 - val_accuracy: 0.3827 - val_loss: 1.0942
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3557 - loss: 1.0963 - val_accuracy: 0.3827 - val_loss: 1.0941
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3567 - loss: 1.0976 - val_accuracy: 0.3827 - val_loss: 1.0937
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3380 - loss: 1.1037 - val_accuracy: 0.3827 - val_loss: 1.0940
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0940
#
# Fold 5
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3354 - loss: 1.3767 - val_accuracy: 0.3333 - val_loss: 1.1389
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3630 - loss: 1.1216 - val_accuracy: 0.3333 - val_loss: 1.0987
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3833 - loss: 1.0889 - val_accuracy: 0.3333 - val_loss: 1.0953
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3381 - loss: 1.0898 - val_accuracy: 0.3333 - val_loss: 1.1063
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3528 - loss: 1.0952 - val_accuracy: 0.3827 - val_loss: 1.0980
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3880 - loss: 1.0953 - val_accuracy: 0.3333 - val_loss: 1.0897
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3608 - loss: 1.0756 - val_accuracy: 0.3333 - val_loss: 1.0860
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3721 - loss: 1.0714 - val_accuracy: 0.3333 - val_loss: 1.0762
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4051 - loss: 1.0585 - val_accuracy: 0.3827 - val_loss: 1.0749
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4542 - loss: 1.0454 - val_accuracy: 0.3827 - val_loss: 1.0688
# Fold 5 Accuracy: 38.27%
# Fold 5 Loss: 1.0688
# Mean Accuracy: 36.21%, Mean Loss: 1.0784
#
# Testing batch_size=16, dropout=0.5, lr=0.001
#
# Fold 1
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.2423 - loss: 2.3570 - val_accuracy: 0.4634 - val_loss: 1.0594
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3480 - loss: 1.1111 - val_accuracy: 0.4634 - val_loss: 1.0963
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3395 - loss: 1.0988 - val_accuracy: 0.4634 - val_loss: 1.0940
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3591 - loss: 1.0976 - val_accuracy: 0.4634 - val_loss: 1.0889
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3282 - loss: 1.1009 - val_accuracy: 0.4634 - val_loss: 1.0847
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3707 - loss: 1.0950 - val_accuracy: 0.4634 - val_loss: 1.0827
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2789 - loss: 1.1031 - val_accuracy: 0.4634 - val_loss: 1.0915
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2775 - loss: 1.1001 - val_accuracy: 0.4634 - val_loss: 1.0877
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3307 - loss: 1.0991 - val_accuracy: 0.4634 - val_loss: 1.0783
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3391 - loss: 1.0954 - val_accuracy: 0.4634 - val_loss: 1.0833
# Fold 1 Accuracy: 46.34%
# Fold 1 Loss: 1.0833
#
# Fold 2
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.2986 - loss: 2.2919 - val_accuracy: 0.3827 - val_loss: 1.2559
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3539 - loss: 1.1757 - val_accuracy: 0.3086 - val_loss: 1.0987
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3246 - loss: 1.0973 - val_accuracy: 0.3827 - val_loss: 1.0949
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3671 - loss: 1.0960 - val_accuracy: 0.3827 - val_loss: 1.0943
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3895 - loss: 1.0912 - val_accuracy: 0.3827 - val_loss: 1.0944
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4353 - loss: 1.0777 - val_accuracy: 0.3827 - val_loss: 1.0945
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3755 - loss: 1.0930 - val_accuracy: 0.3827 - val_loss: 1.0944
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4028 - loss: 1.0893 - val_accuracy: 0.3827 - val_loss: 1.0945
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3554 - loss: 1.0967 - val_accuracy: 0.3827 - val_loss: 1.0944
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4203 - loss: 1.0848 - val_accuracy: 0.3827 - val_loss: 1.0948
# Fold 2 Accuracy: 38.27%
# Fold 2 Loss: 1.0948
#
# Fold 3
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.4022 - loss: 2.8333 - val_accuracy: 0.3333 - val_loss: 1.0961
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3917 - loss: 1.0937 - val_accuracy: 0.3333 - val_loss: 1.1009
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4126 - loss: 1.0892 - val_accuracy: 0.3333 - val_loss: 1.1028
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3843 - loss: 1.0925 - val_accuracy: 0.3333 - val_loss: 1.1055
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3687 - loss: 1.0972 - val_accuracy: 0.3333 - val_loss: 1.1045
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4283 - loss: 1.0841 - val_accuracy: 0.3333 - val_loss: 1.1068
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3838 - loss: 1.0945 - val_accuracy: 0.3333 - val_loss: 1.1011
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4119 - loss: 1.0889 - val_accuracy: 0.3333 - val_loss: 1.1055
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3738 - loss: 1.0987 - val_accuracy: 0.3333 - val_loss: 1.1050
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4028 - loss: 1.0885 - val_accuracy: 0.3333 - val_loss: 1.1017
# Fold 3 Accuracy: 33.33%
# Fold 3 Loss: 1.1017
#
# Fold 4
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.3659 - loss: 2.3044 - val_accuracy: 0.3827 - val_loss: 1.1023
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3527 - loss: 1.1145 - val_accuracy: 0.3827 - val_loss: 1.0962
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3863 - loss: 1.0942 - val_accuracy: 0.3827 - val_loss: 1.0946
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4208 - loss: 1.0880 - val_accuracy: 0.3827 - val_loss: 1.0946
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4060 - loss: 1.0895 - val_accuracy: 0.3827 - val_loss: 1.0946
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4071 - loss: 1.0883 - val_accuracy: 0.3827 - val_loss: 1.0937
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.3925 - loss: 1.0937 - val_accuracy: 0.3827 - val_loss: 1.0938
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3957 - loss: 1.0881 - val_accuracy: 0.3827 - val_loss: 1.0949
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3708 - loss: 1.0974 - val_accuracy: 0.3827 - val_loss: 1.0946
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4100 - loss: 1.0904 - val_accuracy: 0.3827 - val_loss: 1.0946
# Fold 4 Accuracy: 38.27%
# Fold 4 Loss: 1.0946
#
# Fold 5
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.4335 - loss: 2.3006 - val_accuracy: 0.3333 - val_loss: 1.1020
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3738 - loss: 1.1003 - val_accuracy: 0.3333 - val_loss: 1.1137
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3712 - loss: 1.1041 - val_accuracy: 0.3333 - val_loss: 1.1004
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3376 - loss: 1.0941 - val_accuracy: 0.3333 - val_loss: 1.1026
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.4058 - loss: 1.0904 - val_accuracy: 0.3333 - val_loss: 1.1040
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.4243 - loss: 1.0828 - val_accuracy: 0.3333 - val_loss: 1.1060
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4056 - loss: 1.0876 - val_accuracy: 0.3333 - val_loss: 1.1071
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3881 - loss: 1.0933 - val_accuracy: 0.3333 - val_loss: 1.1049
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4110 - loss: 1.0878 - val_accuracy: 0.3333 - val_loss: 1.1062
# Epoch 10/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.3650 - loss: 1.0976 - val_accuracy: 0.3333 - val_loss: 1.1063
# Fold 5 Accuracy: 33.33%
# Fold 5 Loss: 1.1063
# Mean Accuracy: 37.91%, Mean Loss: 1.0961
#
# Testing batch_size=32, dropout=0.3, lr=0.0005
#
# Fold 1
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.3429 - loss: 1.3264 - val_accuracy: 0.4634 - val_loss: 1.0873
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3311 - loss: 1.1136 - val_accuracy: 0.2439 - val_loss: 1.1149
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.2892 - loss: 1.1125 - val_accuracy: 0.3537 - val_loss: 1.1019
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.3168 - loss: 1.1005 - val_accuracy: 0.3780 - val_loss: 1.0943
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3547 - loss: 1.0947 - val_accuracy: 0.2927 - val_loss: 1.1044
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3286 - loss: 1.1151 - val_accuracy: 0.4512 - val_loss: 1.0739
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3670 - loss: 1.0843 - val_accuracy: 0.4634 - val_loss: 1.0550
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3414 - loss: 1.0894 - val_accuracy: 0.4024 - val_loss: 1.0439
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3932 - loss: 1.0730 - val_accuracy: 0.3537 - val_loss: 1.1338
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.3535 - loss: 1.1355 - val_accuracy: 0.4634 - val_loss: 1.0927
# Fold 1 Accuracy: 46.34%
# Fold 1 Loss: 1.0927
#
# Fold 2
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.3266 - loss: 1.4626 - val_accuracy: 0.3086 - val_loss: 1.1239
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.2862 - loss: 1.1463 - val_accuracy: 0.3580 - val_loss: 1.0947
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.4136 - loss: 1.0895 - val_accuracy: 0.3580 - val_loss: 1.0921
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.3912 - loss: 1.0957 - val_accuracy: 0.3580 - val_loss: 1.0921
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3666 - loss: 1.0909 - val_accuracy: 0.3827 - val_loss: 1.0909
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4342 - loss: 1.0621 - val_accuracy: 0.3457 - val_loss: 1.0950
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3855 - loss: 1.0799 - val_accuracy: 0.3827 - val_loss: 1.0835
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.4173 - loss: 1.0662 - val_accuracy: 0.3704 - val_loss: 1.0719
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4242 - loss: 1.0495 - val_accuracy: 0.3704 - val_loss: 1.0797
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4695 - loss: 1.0309 - val_accuracy: 0.3580 - val_loss: 1.1017
# Fold 2 Accuracy: 35.80%
# Fold 2 Loss: 1.1017
#
# Fold 3
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.3522 - loss: 1.5849 - val_accuracy: 0.2840 - val_loss: 1.1189
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3041 - loss: 1.1174 - val_accuracy: 0.3333 - val_loss: 1.1148
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4130 - loss: 1.0839 - val_accuracy: 0.3333 - val_loss: 1.0906
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3337 - loss: 1.1009 - val_accuracy: 0.3333 - val_loss: 1.0914
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4118 - loss: 1.0788 - val_accuracy: 0.4691 - val_loss: 1.0749
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3590 - loss: 1.0881 - val_accuracy: 0.3333 - val_loss: 1.0832
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3759 - loss: 1.0779 - val_accuracy: 0.4815 - val_loss: 1.0585
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4142 - loss: 1.0701 - val_accuracy: 0.3210 - val_loss: 1.0616
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.4234 - loss: 1.0478 - val_accuracy: 0.4074 - val_loss: 1.0394
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4521 - loss: 1.0416 - val_accuracy: 0.3951 - val_loss: 1.0662
# Fold 3 Accuracy: 39.51%
# Fold 3 Loss: 1.0662
#
# Fold 4
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.3082 - loss: 1.8276 - val_accuracy: 0.3827 - val_loss: 1.1112
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3537 - loss: 1.1143 - val_accuracy: 0.3086 - val_loss: 1.1007
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.3503 - loss: 1.0938 - val_accuracy: 0.3827 - val_loss: 1.0914
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3637 - loss: 1.0990 - val_accuracy: 0.3827 - val_loss: 1.0874
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3862 - loss: 1.0902 - val_accuracy: 0.3827 - val_loss: 1.0845
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3754 - loss: 1.0982 - val_accuracy: 0.3827 - val_loss: 1.0747
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.3638 - loss: 1.0832 - val_accuracy: 0.3827 - val_loss: 1.0668
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3634 - loss: 1.0909 - val_accuracy: 0.3827 - val_loss: 1.0724
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4108 - loss: 1.0744 - val_accuracy: 0.4074 - val_loss: 1.0734
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3846 - loss: 1.0851 - val_accuracy: 0.4321 - val_loss: 1.0590
# Fold 4 Accuracy: 43.21%
# Fold 4 Loss: 1.0590
#
# Fold 5
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.3048 - loss: 1.4535 - val_accuracy: 0.3333 - val_loss: 1.1432
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3278 - loss: 1.1230 - val_accuracy: 0.3333 - val_loss: 1.1007
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3792 - loss: 1.1004 - val_accuracy: 0.3333 - val_loss: 1.0996
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3818 - loss: 1.0877 - val_accuracy: 0.3333 - val_loss: 1.1108
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4097 - loss: 1.0733 - val_accuracy: 0.3580 - val_loss: 1.0913
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.4053 - loss: 1.0690 - val_accuracy: 0.3333 - val_loss: 1.0865
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3790 - loss: 1.0681 - val_accuracy: 0.3457 - val_loss: 1.0978
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4098 - loss: 1.0762 - val_accuracy: 0.3457 - val_loss: 1.0767
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.4452 - loss: 1.0521 - val_accuracy: 0.3333 - val_loss: 1.1304
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.3895 - loss: 1.0817 - val_accuracy: 0.3580 - val_loss: 1.0801
# Fold 5 Accuracy: 35.80%
# Fold 5 Loss: 1.0801
# Mean Accuracy: 40.13%, Mean Loss: 1.0799
#
# Testing batch_size=32, dropout=0.3, lr=0.001
#
# Fold 1
# Epoch 1/10

# %%
batch_size=16, dropout=0.3, lr=0.0005, Mean Accuracy: 41.37%

# %%
batch_size': 32, 'dropout': 0.5, 'learning_rate': 0.0005, 'accuracy': 0.4063535094261169
